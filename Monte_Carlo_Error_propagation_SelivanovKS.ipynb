# %%
import numpy as np

# %matplotlib notebook

import matplotlib.pyplot as plt
plt.xkcd()

# %%
#Part 1
M1 = 40 * 10**4
M1_err = 0.05 * 10**4
M2 = 30 * 10**4
M2_err = 0.1 * 10**4
r = 3.2
r_err = 0.01
G = 6.67384 * 10**(-11)

# %%
F = G * M1 * M2 / r**2
F_err = np.sqrt((G * M2 / r**2)**2 * M1_err**2 + (G * M1 / r**2)**2 * M2_err**2 + (-2 * G * M1 * M2 / r**3)**2 * r_err**2)

print('F =', F, '+/-', F_err)
# Out:
# F = 0.7820906249999999 +/- 0.005625407272639265

# %%
N = 1000000
M1_m = np.random.normal(M1, M1_err, N)
M2_m = np.random.normal(M2, M2_err, N)
r_m = np.random.normal(r, r_err, N)
F_m = G * M1_m * M2_m / r_m ** 2

print('F =', np.mean(F_m), '+/-', np.std(F_m))
# Out:
# F = 0.7821167054801014 +/- 0.005627880502453863

# %%
x = np.linspace(0.76, 0.81, 1000)
y = 1 / (F_err * np.sqrt(2 * np.pi)) *  np.exp(-(x - F)**2 / (2 * F_err**2))

plt.hist(F_m, bins=50, range=[0.76, 0.81], density=True)
plt.plot(x, y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Part 2
M1 = 40 * 10**4
M1_err = 2 * 10**4
M2 = 30 * 10**4
M2_err = 10 * 10**4
r = 3.2
r_err = 1
G = 6.67384 * 10**(-11)

# %%
F = G * M1 * M2 / r**2
F_err = np.sqrt((G * M2 / r**2)**2 * M1_err**2 + (G * M1 / r**2)**2 * M2_err**2 + (-2 * G * M1 * M2 / r**3)**2 * r_err**2)

print('F =', F, '+/-', F_err)
# Out:
# F = 0.7820906249999999 +/- 0.5553593043410235

# %%
N = 1000000
M1_m = np.random.normal(M1, M1_err, N)
M2_m = np.random.normal(M2, M2_err, N)
r_m = np.random.normal(r, r_err, N)
F_m = G * M1_m * M2_m / r_m ** 2

print('F =', np.mean(F_m), '+/-', np.std(F_m))
# Out:
# F = 58536.38302512832 +/- 58096855.75608801

# %%
x = np.linspace(-2, 7, 1000)
y = 1 / (F_err * np.sqrt(2 * np.pi)) *  np.exp(-(x - F)**2 / (2 * F_err**2))

plt.hist(F_m, bins=50, range=[-2, 7], density=True)
plt.plot(x, y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
